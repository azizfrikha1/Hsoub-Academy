# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from mlxtend) (1.18.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\python314\lib\site-packages (from mlxtend) (2.4.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\python314\lib\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\python314\lib\site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\python314\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from pandas>=2.3.3->mlxtend) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\aziz1\appdata\roaming\python\python314\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 7.7 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
transactions = [['Bread', 'Milk'],
                ['Bread', 'Cheese', 'Juice', 'Eggs'],
                ['Milk', 'Cheese', 'Juice', 'Coke' ],
                ['Bread', 'Milk', 'Cheese', 'Juice'],
                ['Bread', 'Milk', 'Cheese', 'Coke']]


from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()

te.fit(transactions)

rows = te.transform(transactions)
print(rows)
# Out:
# [[ True False False False False  True]
#  [ True  True False  True  True False]
#  [False  True  True False  True  True]
#  [ True  True False False  True  True]
#  [ True  True  True False False  True]]

# %%
import pandas as pd

df_transactions = pd.DataFrame(rows, columns=te.columns_)
df_transactions
# Out:
#    Bread  Cheese   Coke   Eggs  Juice   Milk
# 0   True   False  False  False  False   True
# 1   True    True  False   True   True  False
# 2  False    True   True  False   True   True
# 3   True    True  False  False   True   True
# 4   True    True   True  False  False   True

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df_transactions, min_support=0.4, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                           itemsets  length
# 0       0.8                 frozenset({Bread})       1
# 1       0.8                frozenset({Cheese})       1
# 2       0.4                  frozenset({Coke})       1
# 3       0.6                 frozenset({Juice})       1
# 4       0.8                  frozenset({Milk})       1
# 5       0.6         frozenset({Bread, Cheese})       2
# 6       0.4          frozenset({Bread, Juice})       2
# 7       0.6           frozenset({Bread, Milk})       2
# 8       0.4          frozenset({Cheese, Coke})       2
# 9       0.6         frozenset({Juice, Cheese})       2
# 10      0.6          frozenset({Cheese, Milk})       2
# 11      0.4            frozenset({Milk, Coke})       2
# 12      0.4           frozenset({Juice, Milk})       2
# 13      0.4  frozenset({Bread, Juice, Cheese})       3
# 14      0.4   frozenset({Bread, Cheese, Milk})       3
# 15      0.4    frozenset({Milk, Cheese, Coke})       3
# 16      0.4   frozenset({Juice, Cheese, Milk})       3

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

rules = rules.sort_values(['confidence'], ascending =[False])
rules
# Out:
#                    antecedents                 consequents  \
# 10           frozenset({Coke})           frozenset({Milk})
# 5            frozenset({Coke})         frozenset({Cheese})
# 6           frozenset({Juice})         frozenset({Cheese})
# 19   frozenset({Cheese, Coke})           frozenset({Milk})
# 20     frozenset({Milk, Coke})         frozenset({Cheese})
# 22           frozenset({Coke})   frozenset({Cheese, Milk})
# 24    frozenset({Juice, Milk})         frozenset({Cheese})
# 12   frozenset({Bread, Juice})         frozenset({Cheese})
# 3           frozenset({Bread})           frozenset({Milk})
# 0           frozenset({Bread})         frozenset({Cheese})
# 1          frozenset({Cheese})          frozenset({Bread})
# 4            frozenset({Milk})          frozenset({Bread})
# 9            frozenset({Milk})         frozenset({Cheese})
# 7          frozenset({Cheese})          frozenset({Juice})
# 8          frozenset({Cheese})           frozenset({Milk})
# 2           frozenset({Juice})          frozenset({Bread})
# 11          frozenset({Juice})           frozenset({Milk})
# 13  frozenset({Bread, Cheese})          frozenset({Juice})
# 14  frozenset({Juice, Cheese})          frozenset({Bread})
# 18   frozenset({Cheese, Milk})          frozenset({Bread})
# 17    frozenset({Bread, Milk})         frozenset({Cheese})
# 16  frozenset({Bread, Cheese})           frozenset({Milk})
# 15          frozenset({Juice})  frozenset({Bread, Cheese})
# 21   frozenset({Cheese, Milk})           frozenset({Coke})
# 23  frozenset({Juice, Cheese})           frozenset({Milk})
# 25   frozenset({Cheese, Milk})          frozenset({Juice})
# 26          frozenset({Juice})   frozenset({Cheese, Milk})
#
#     antecedent support  consequent support  support  confidence      lift  \
# 10                 0.4                 0.8      0.4    1.000000  1.250000
# 5                  0.4                 0.8      0.4    1.000000  1.250000
# 6                  0.6                 0.8      0.6    1.000000  1.250000
# 19                 0.4                 0.8      0.4    1.000000  1.250000
# 20                 0.4                 0.8      0.4    1.000000  1.250000
# 22                 0.4                 0.6      0.4    1.000000  1.666667
# 24                 0.4                 0.8      0.4    1.000000  1.250000
# 12                 0.4                 0.8      0.4    1.000000  1.250000
# 3                  0.8                 0.8      0.6    0.750000  0.937500
# 0                  0.8                 0.8      0.6    0.750000  0.937500
# 1                  0.8                 0.8      0.6    0.750000  0.937500
# 4                  0.8                 0.8      0.6    0.750000  0.937500
# 9                  0.8                 0.8      0.6    0.750000  0.937500
# 7                  0.8                 0.6      0.6    0.750000  1.250000
# 8                  0.8                 0.8      0.6    0.750000  0.937500
# 2                  0.6                 0.8      0.4    0.666667  0.833333
# 11                 0.6                 0.8      0.4    0.666667  0.833333
# 13                 0.6                 0.6      0.4    0.666667  1.111111
# 14                 0.6                 0.8      0.4    0.666667  0.833333
# 18                 0.6                 0.8      0.4    0.666667  0.833333
# 17                 0.6                 0.8      0.4    0.666667  0.833333
# 16                 0.6                 0.8      0.4    0.666667  0.833333
# 15                 0.6                 0.6      0.4    0.666667  1.111111
# 21                 0.6                 0.4      0.4    0.666667  1.666667
# 23                 0.6                 0.8      0.4    0.666667  0.833333
# 25                 0.6                 0.6      0.4    0.666667  1.111111
# 26                 0.6                 0.6      0.4    0.666667  1.111111
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 10               1.0      0.08         inf       0.333333  0.500000
# 5                1.0      0.08         inf       0.333333  0.500000
# 6                1.0      0.12         inf       0.500000  0.750000
# 19               1.0      0.08         inf       0.333333  0.500000
# 20               1.0      0.08         inf       0.333333  0.500000
# 22               1.0      0.16         inf       0.666667  0.666667
# 24               1.0      0.08         inf       0.333333  0.500000
# 12               1.0      0.08         inf       0.333333  0.500000
# 3                1.0     -0.04         0.8      -0.250000  0.600000
# 0                1.0     -0.04         0.8      -0.250000  0.600000
# 1                1.0     -0.04         0.8      -0.250000  0.600000
# 4                1.0     -0.04         0.8      -0.250000  0.600000
# 9                1.0     -0.04         0.8      -0.250000  0.600000
# 7                1.0      0.12         1.6       1.000000  0.750000
# 8                1.0     -0.04         0.8      -0.250000  0.600000
# 2                1.0     -0.08         0.6      -0.333333  0.400000
# 11               1.0     -0.08         0.6      -0.333333  0.400000
# 13               1.0      0.04         1.2       0.250000  0.500000
# 14               1.0     -0.08         0.6      -0.333333  0.400000
# 18               1.0     -0.08         0.6      -0.333333  0.400000
# 17               1.0     -0.08         0.6      -0.333333  0.400000
# 16               1.0     -0.08         0.6      -0.333333  0.400000
# 15               1.0      0.04         1.2       0.250000  0.500000
# 21               1.0      0.16         1.8       1.000000  0.666667
# 23               1.0     -0.08         0.6      -0.333333  0.400000
# 25               1.0      0.04         1.2       0.250000  0.500000
# 26               1.0      0.04         1.2       0.250000  0.500000
#
#     certainty  kulczynski
# 10   1.000000    0.750000
# 5    1.000000    0.750000
# 6    1.000000    0.875000
# 19   1.000000    0.750000
# 20   1.000000    0.750000
# 22   1.000000    0.833333
# 24   1.000000    0.750000
# 12   1.000000    0.750000
# 3   -0.250000    0.750000
# 0   -0.250000    0.750000
# 1   -0.250000    0.750000
# 4   -0.250000    0.750000
# 9   -0.250000    0.750000
# 7    0.375000    0.875000
# 8   -0.250000    0.750000
# 2   -0.666667    0.583333
# 11  -0.666667    0.583333
# 13   0.166667    0.666667
# 14  -0.666667    0.583333
# 18  -0.666667    0.583333
# 17  -0.666667    0.583333
# 16  -0.666667    0.583333
# 15   0.166667    0.666667
# 21   0.444444    0.833333
# 23  -0.666667    0.583333
# 25   0.166667    0.666667
# 26   0.166667    0.666667

# %%
from matplotlib import pyplot as plt
from pandas.plotting import parallel_coordinates

rules['antecedent'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))

rules['consequent'] = rules['consequents'].apply(lambda a: ','.join(list(a)))

rules['rule_n'] = rules.index

coords=rules[['antecedent','consequent','rule_n']]

plt.figure(figsize=(4,8))

parallel_coordinates(coords, 'rule_n')

plt.legend([])

plt.grid(True)
plt.show()

# %%
import seaborn as sns

matrix = rules.pivot(index = 'antecedent', columns = 'consequent', values= 'confidence')
matrix
# Out:
# consequent       Bread  Bread,Cheese    Cheese  Cheese,Milk      Coke  \
# antecedent
# Bread              NaN           NaN  0.750000          NaN       NaN
# Bread,Cheese       NaN           NaN       NaN          NaN       NaN
# Bread,Juice        NaN           NaN  1.000000          NaN       NaN
# Bread,Milk         NaN           NaN  0.666667          NaN       NaN
# Cheese        0.750000           NaN       NaN          NaN       NaN
# Cheese,Coke        NaN           NaN       NaN          NaN       NaN
# Cheese,Milk   0.666667           NaN       NaN          NaN  0.666667
# Coke               NaN           NaN  1.000000     1.000000       NaN
# Juice         0.666667      0.666667  1.000000     0.666667       NaN
# Juice,Cheese  0.666667           NaN       NaN          NaN       NaN
# Juice,Milk         NaN           NaN  1.000000          NaN       NaN
# Milk          0.750000           NaN  0.750000          NaN       NaN
# Milk,Coke          NaN           NaN  1.000000          NaN       NaN
#
# consequent       Juice      Milk
# antecedent
# Bread              NaN  0.750000
# Bread,Cheese  0.666667  0.666667
# Bread,Juice        NaN       NaN
# Bread,Milk         NaN       NaN
# Cheese        0.750000  0.750000
# Cheese,Coke        NaN  1.000000
# Cheese,Milk   0.666667       NaN
# Coke               NaN  1.000000
# Juice              NaN  0.666667
# Juice,Cheese       NaN  0.666667
# Juice,Milk         NaN       NaN
# Milk               NaN       NaN
# Milk,Coke          NaN       NaN

# %%
sns.heatmap(matrix, annot = True)

plt.yticks(rotation=0)

plt.xticks(rotation=90)
plt.show()

# %%
def predict(items, rules, max_results= 6):
    
    preds = rules[rules['antecedents'] == items]
    
    preds = preds[['consequent','confidence']]
    
    preds.sort_values('confidence', ascending=False)
    
    return preds[:max_results]

preds = predict({'Cheese','Milk'}, rules)
preds
# Out:
#    consequent  confidence
# 18      Bread    0.666667
# 21       Coke    0.666667
# 25      Juice    0.666667
