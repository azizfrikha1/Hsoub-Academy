# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3, 4], [4, 5, 6, 5]])

# %%
arr.shape
# Out:
# (2, 4)

# %%
arr.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 8

# %%
a = np.array([1, 2, 3, 4])

# %%
a + 1
# Out:
# array([2, 3, 4, 5])

# %%
2 * a
# Out:
# array([2, 4, 6, 8])

# %%
a**2
# Out:
# array([ 1,  4,  9, 16])

# %%
np.power(a, 2)
# Out:
# array([ 1,  4,  9, 16])

# %%
np.sum(a)
# Out:
# np.int64(10)

# %%
a.sum()
# Out:
# np.int64(10)

# %%
x = np.array([[1, 1], [2, 2]])
x
# Out:
# array([[1, 1],
#        [2, 2]])

# %%
x.sum(axis=0)
# Out:
# array([3, 3])

# %%
x.sum(axis=1)
# Out:
# array([2, 4])

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[2,1],[4,3]])

a == b
# Out:
# array([[False, False],
#        [False, False]])

# %%
np.array_equal(a, b)
# Out:
# False
