# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=10000, n_features=20, n_informative=5, n_redundant=15, random_state=1)

print(X.shape, y.shape)
# Out:
# (10000, 20) (10000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7000, 20) (3000, 20) (7000,) (3000,)

# %%
values = [i for i in range(1, 21)]

# %%
train_scores, test_scores = list(), list()

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

for i in values:
    model = DecisionTreeClassifier(max_depth=i)

    model.fit(X_train, y_train)

    train_yhat = model.predict(X_train)
    train_acc = accuracy_score(y_train, train_yhat)
    train_scores.append(train_acc)

    test_yhat = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_yhat)
    test_scores.append(test_acc)

    print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# Out:
# >1, train: 0.765, test: 0.762
# >2, train: 0.810, test: 0.805
# >3, train: 0.884, test: 0.875
# >4, train: 0.901, test: 0.895
# >5, train: 0.911, test: 0.903
# >6, train: 0.927, test: 0.916
# >7, train: 0.938, test: 0.924
# >8, train: 0.952, test: 0.921
# >9, train: 0.959, test: 0.923
# >10, train: 0.968, test: 0.920
# >11, train: 0.973, test: 0.919
# >12, train: 0.979, test: 0.923
# >13, train: 0.983, test: 0.922
# >14, train: 0.989, test: 0.919
# >15, train: 0.991, test: 0.916
# >16, train: 0.994, test: 0.915
# >17, train: 0.995, test: 0.915
# >18, train: 0.998, test: 0.911
# >19, train: 0.999, test: 0.917
# >20, train: 0.999, test: 0.915
