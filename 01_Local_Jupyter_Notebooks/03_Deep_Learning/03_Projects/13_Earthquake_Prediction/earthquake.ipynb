# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("dataset.csv")

df = df[['Date' ,'Time' ,'Latitude' ,'Longitude' ,'Depth' ,'Magnitude']]
df
# Out:
#              Date      Time  Latitude  Longitude   Depth  Magnitude
# 0      01/02/1965  13:44:18   19.2460   145.6160  131.60        6.0
# 1      01/04/1965  11:29:49    1.8630   127.3520   80.00        5.8
# 2      01/05/1965  18:05:58  -20.5790  -173.9720   20.00        6.2
# 3      01/08/1965  18:49:43  -59.0760   -23.5570   15.00        5.8
# 4      01/09/1965  13:32:50   11.9380   126.4270   15.00        5.8
# ...           ...       ...       ...        ...     ...        ...
# 23407  12/28/2016   8:22:12   38.3917  -118.8941   12.30        5.6
# 23408  12/28/2016   9:13:47   38.3777  -118.8957    8.80        5.5
# 23409  12/28/2016  12:38:51   36.9179   140.4262   10.00        5.9
# 23410  12/29/2016  22:30:19   -9.0283   118.6639   79.00        6.3
# 23411  12/30/2016  20:08:28   37.3973   141.4103   11.94        5.5
#
# [23412 rows x 6 columns]

# %%
import datetime

current_datetime = datetime.datetime.now()
print("Now is : ", current_datetime)

timestamp = current_datetime.timestamp()

print("Time stamp (seconds): ", timestamp)
# Out:
# Now is :  2026-07-29 06:31:21.168565
# Time stamp (seconds):  1785303081.168565

# %%
import datetime

timestamps = []
for _, row in df.iterrows():
    try:
        d = row['Date']
        t = row['Time']
        
        full_date_string= d + " " + t
        
        full_date = datetime.datetime.strptime(full_date_string, '%m/%d/%Y %H:%M:%S')
        
        timestamp = full_date.timestamp()
        
        timestamps.append(timestamp)
        
    except Exception:
        timestamps.append('ValueError')

# %%
df['Timestamp'] = timestamps

df = df.drop(['Date', 'Time'], axis=1)

df = df[df.Timestamp != 'ValueError']

df['Timestamp'] = df['Timestamp'].astype(float)

df.head()
# Out:
#       Latitude  Longitude  Depth  Magnitude  Timestamp
# 1457    24.185    102.543   11.3        7.1   316841.0
# 1458    23.984    102.732   15.0        5.9   384550.0
# 1459    -9.583    151.493   15.0        6.3   448554.0
# 1460    15.785    -59.808   36.7        6.0   543374.0
# 1461   -34.850    178.782  199.4        6.8   663161.0

# %%
# !pip install basemap
# Out:
# Requirement already satisfied: basemap in C:\Users\aziz1\envs\churn_env\Lib\site-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (2.3.5)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (3.10.9)
# Requirement already satisfied: pyproj<3.8,>=3.0 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.5.0)
# Requirement already satisfied: pillow>=8 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from pyproj<3.8,>=3.0->basemap) (2026.7.22)
# Requirement already satisfied: six>=1.5 in C:\Users\aziz1\envs\churn_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->basemap) (1.17.0)

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap()

longitudes = df["Longitude"].tolist()

latitudes = df["Latitude"].tolist()

x,y = m(longitudes,latitudes)

fig = plt.figure(figsize=(12,10))

plt.title("All affected areas")

m.plot(x, y, "o", markersize = 2, color = 'blue')

m.drawcoastlines()

m.fillcontinents(color='coral',lake_color='aqua')

m.drawmapboundary()

m.drawcountries()

plt.show()

# %%
X = df[['Latitude', 'Longitude', 'Timestamp']].values

y = df[['Depth', 'Magnitude']].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout

model = Sequential()
model.add(Input(shape=(3,)))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='linear'))

# %%
model.compile(optimizer='adam', loss='mean_absolute_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 29.6890 - val_loss: 27.3780
# Epoch 2/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 27.0869 - val_loss: 27.1550
# Epoch 3/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 26.9318 - val_loss: 27.0549
# Epoch 4/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.7574 - val_loss: 27.0506
# Epoch 5/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.7234 - val_loss: 27.0282
# Epoch 6/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.6710 - val_loss: 27.0157
# Epoch 7/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.6857 - val_loss: 27.0118
# Epoch 8/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 26.6137 - val_loss: 27.0624
# Epoch 9/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 26.6319 - val_loss: 26.9998
# Epoch 10/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.6351 - val_loss: 27.0155
# Epoch 11/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.6086 - val_loss: 26.9919
# Epoch 12/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.6136 - val_loss: 26.9983
# Epoch 13/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.5979 - val_loss: 26.9692
# Epoch 14/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5583 - val_loss: 26.9526
# Epoch 15/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 26.5425 - val_loss: 26.9321
# Epoch 16/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.4934 - val_loss: 26.8619
# Epoch 17/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26.4935 - val_loss: 26.8174
# Epoch 18/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.4159 - val_loss: 26.7951
# Epoch 19/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.4032 - val_loss: 26.7225
# Epoch 20/20
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 26.3455 - val_loss: 26.6977

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss by Epoch')
plt.legend()
plt.show()

# %%
model.save('earthquacke_model.keras')

import pickle
scaler_path = 'earthquacke_scalar'

with open(scaler_path, 'wb') as file:
    pickle.dump(scaler, file)

# %%
latitude = 19
longitude = 145

current_datetime = datetime.datetime.now()

timestamp = current_datetime.timestamp()

from keras.models import load_model

model = load_model('earthquacke_model.keras')

scaler_path = 'earthquacke_scalar'
with open(scaler_path, 'rb') as file:
    scaler = pickle.load(file)

new_data = np.array([[latitude, longitude, timestamp]])

scaled_data = scaler.transform(new_data)

predictions = model.predict(scaled_data)

Depth = predictions[0][0]
Magnitude = predictions[0][1]
print("Predicted Depth: ", Depth)
print("Predicted Magnitude: ", Magnitude)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted Depth:  26.951078
# Predicted Magnitude:  5.8055983
