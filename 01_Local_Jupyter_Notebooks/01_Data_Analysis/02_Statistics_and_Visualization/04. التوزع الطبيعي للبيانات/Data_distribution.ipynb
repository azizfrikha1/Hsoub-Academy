# %%
import pandas as pd

df = pd.read_csv("Students_Marks.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      20 non-null     int64
#  1   Math    20 non-null     int64
#  2   Phy     20 non-null     int64
#  3   Lang    20 non-null     int64
# dtypes: int64(4)
# memory usage: 772.0 bytes

# %%
df.describe()
# Out:
#              Id       Math        Phy       Lang
# count  20.00000  20.000000  20.000000  20.000000
# mean   10.50000  57.750000  68.500000  63.250000
# std     5.91608  14.642674  14.876686  11.728844
# min     1.00000  30.000000  40.000000  45.000000
# 25%     5.75000  48.750000  60.000000  53.750000
# 50%    10.50000  60.000000  67.500000  62.500000
# 75%    15.25000  70.000000  80.000000  71.250000
# max    20.00000  80.000000  95.000000  85.000000

# %%
df.plot(kind='density',subplots=True, layout=(4,1), sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>]], dtype=object)

# %%
skew = df.skew()
skew
# Out:
# Id      0.000000
# Math   -0.258904
# Phy    -0.102308
# Lang    0.034591
# dtype: float64
