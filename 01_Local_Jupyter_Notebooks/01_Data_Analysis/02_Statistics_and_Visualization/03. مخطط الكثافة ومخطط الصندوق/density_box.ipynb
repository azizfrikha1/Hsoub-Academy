# %%
import pandas as pd


df = pd.read_csv("Students_exams.csv")

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in c:\python314\lib\site-packages (from scipy) (2.4.5)
# Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.3 MB 7.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.9/37.3 MB 13.5 MB/s eta 0:00:03
#    -------- ------------------------------- 7.9/37.3 MB 16.2 MB/s eta 0:00:02
#    ------------ --------------------------- 11.8/37.3 MB 17.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 14.9/37.3 MB 17.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.9/37.3 MB 16.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/37.3 MB 16.9 MB/s eta 0:00:01
#    --------------------------- ------------ 25.4/37.3 MB 16.6 MB/s eta 0:00:01
#    ------------------------------ --------- 28.8/37.3 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.5/37.3 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------  36.7/37.3 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 16.4 MB/s  0:00:02
# Installing collected packages: scipy
# Successfully installed scipy-1.18.0
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['math score'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='density',subplots=True, layout=(2,2), sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df = pd.read_csv("Students_exams_error.csv")

df['writing score'].plot(kind='box')
# Out:
# <Axes: >

# %%
df = pd.read_csv("Students_exams.csv")

df['writing score'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='box',subplots=True, layout=(2,2), sharex=False)
# Out:
# math score          Axes(0.125,0.53;0.352273x0.35)
# reading score    Axes(0.547727,0.53;0.352273x0.35)
# writing score       Axes(0.125,0.11;0.352273x0.35)
# dtype: object
