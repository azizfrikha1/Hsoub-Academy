# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots easier to read in the notebook
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_theme(style='whitegrid', context='talk')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'

# %%
df = pd.read_csv('Bank_Marketing_Campaign.csv')
df
# Out:
#              id  customer_age     job_type  marital  education default  \
# 0      id_43823          28.0   management   single   tertiary      no
# 1      id_32289          34.0  blue-collar  married  secondary      no
# 2      id_10523          46.0   technician  married  secondary      no
# 3      id_43951          34.0     services   single  secondary      no
# 4      id_40992          41.0  blue-collar  married    primary      no
# ...         ...           ...          ...      ...        ...     ...
# 31642  id_27290          58.0       admin.  married  secondary      no
# 31643  id_20428          51.0   management  married   tertiary      no
# 31644  id_44679          41.0   unemployed  married    primary      no
# 31645   id_4841          48.0     services  married  secondary      no
# 31646   id_1723          38.0   technician   single   tertiary      no
#
#        balance housing_loan personal_loan communication_type  day_of_month  \
# 0        285.0          yes            no            unknown            26
# 1        934.0           no           yes           cellular            18
# 2        656.0           no            no           cellular             5
# 3          2.0          yes            no            unknown            20
# 4       1352.0          yes            no           cellular            13
# ...        ...          ...           ...                ...           ...
# 31642    567.0          yes            no           cellular             2
# 31643   1072.0           no            no            unknown            20
# 31644    242.0          yes            no            unknown            23
# 31645   2699.0           no            no           cellular            11
# 31646   1045.0           no            no           cellular            18
#
#       month  last_contact_duration  num_contacts_in_campaign  \
# 0       jun                  303.0                       4.0
# 1       nov                  143.0                       2.0
# 2       feb                  101.0                       4.0
# 3       may                  127.0                       3.0
# 4       may                   49.0                       2.0
# ...     ...                    ...                       ...
# 31642   feb                   99.0                       2.0
# 31643   jun                   31.0                       7.0
# 31644   may                   89.0                       2.0
# 31645   aug                  216.0                       6.0
# 31646   aug                  183.0                      10.0
#
#        days_since_prev_campaign_contact  num_contacts_prev_campaign  \
# 0                                   NaN                           0
# 1                                 132.0                           1
# 2                                   NaN                           0
# 3                                   NaN                           0
# 4                                   NaN                           0
# ...                                 ...                         ...
# 31642                             265.0                           3
# 31643                               NaN                           0
# 31644                               NaN                           0
# 31645                               NaN                           0
# 31646                               NaN                           0
#
#       prev_campaign_outcome  term_deposit_subscribed
# 0                   unknown                        0
# 1                     other                        0
# 2                   unknown                        0
# 3                   unknown                        0
# 4                   unknown                        0
# ...                     ...                      ...
# 31642                 other                        0
# 31643               unknown                        0
# 31644               unknown                        0
# 31645               unknown                        0
# 31646               unknown                        0
#
# [31647 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                31647 non-null  str
#  1   customer_age                      31028 non-null  float64
#  2   job_type                          31647 non-null  str
#  3   marital                           31497 non-null  str
#  4   education                         31647 non-null  str
#  5   default                           31647 non-null  str
#  6   balance                           31248 non-null  float64
#  7   housing_loan                      31647 non-null  str
#  8   personal_loan                     31498 non-null  str
#  9   communication_type                31647 non-null  str
#  10  day_of_month                      31647 non-null  int64
#  11  month                             31647 non-null  str
#  12  last_contact_duration             31336 non-null  float64
#  13  num_contacts_in_campaign          31535 non-null  float64
#  14  days_since_prev_campaign_contact  5816 non-null   float64
#  15  num_contacts_prev_campaign        31647 non-null  int64
#  16  prev_campaign_outcome             31647 non-null  str
#  17  term_deposit_subscribed           31647 non-null  int64
# dtypes: float64(5), int64(3), str(10)
# memory usage: 4.3 MB

# %%
null_value_percentage = (df.isnull().sum()/df.shape[0])*100
null_value_percentage.sort_values(ascending = False)
# Out:
# days_since_prev_campaign_contact    81.622271
# customer_age                         1.955952
# balance                              1.260783
# last_contact_duration                0.982716
# marital                              0.473979
# personal_loan                        0.470819
# num_contacts_in_campaign             0.353904
# id                                   0.000000
# default                              0.000000
# job_type                             0.000000
# communication_type                   0.000000
# housing_loan                         0.000000
# education                            0.000000
# month                                0.000000
# day_of_month                         0.000000
# num_contacts_prev_campaign           0.000000
# prev_campaign_outcome                0.000000
# term_deposit_subscribed              0.000000
# dtype: float64

# %%
df.nunique()
# Out:
# id                                  31647
# customer_age                           77
# job_type                               12
# marital                                 3
# education                               4
# default                                 2
# balance                              6563
# housing_loan                            2
# personal_loan                           2
# communication_type                      3
# day_of_month                           31
# month                                  12
# last_contact_duration                1447
# num_contacts_in_campaign               46
# days_since_prev_campaign_contact      511
# num_contacts_prev_campaign             41
# prev_campaign_outcome                   4
# term_deposit_subscribed                 2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_cols = [c for c in df.columns
            if c not in ['id', 'term_deposit_subscribed']
            and df[c].dtype == 'O']
cat_cols

# %%
fig, axes = plt.subplots(5, 2, figsize=(18, 30))
axes = [ax for axes_rows in axes for ax in axes_rows]

for i, column in enumerate(df[cat_cols]):
    df[column].value_counts()[::-1].plot(kind='pie', ax=axes[i], title=column, autopct='%.0f%%', fontsize=12)

# %%
fig, axes = plt.subplots(3, 3, figsize=(20,16))

axes = [ax for axes_rows in axes for ax in axes_rows]

for i, column in enumerate(df[cat_cols]):
    df[column].value_counts()[::-1].plot(kind='barh', ax=axes[i], title=column, fontsize=12)

# %%
fig, axes = plt.subplots(5, 2, figsize=(16, 24))
axes = [ax for axes_rows in axes for ax in axes_rows]

target_col = 'term_deposit_subscribed'

for i, column in enumerate(df[cat_cols]):
    fltr = df[target_col] == 0

    # value_counts().reset_index() returns different column names on
    # pandas < 2.0 (['index', column]) vs pandas >= 2.0 ([column, 'proportion']).
    # Force consistent names so the rest of the cell works on both versions.
    vc_a = df[fltr][column].value_counts(normalize=True).reset_index()
    vc_a.columns = [column, 'count']
    vc_a[target_col] = 0

    vc_b = df[~fltr][column].value_counts(normalize=True).reset_index()
    vc_b.columns = [column, 'count']
    vc_b[target_col] = 1

    # Merge the two frames into one
    result = pd.concat([vc_a, vc_b], ignore_index=True)

    sns.barplot(y=column, x='count', data=result, hue=target_col, ax=axes[i])

plt.tight_layout()
plt.show()

# %%
features = [c for c in df.columns if c not in ['id', 'term_deposit_subscribed']]
num_cols = [c for c in features if c not in cat_cols]
num_cols
# Out:
# ['customer_age',
#  'job_type',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing_loan',
#  'personal_loan',
#  'communication_type',
#  'day_of_month',
#  'month',
#  'last_contact_duration',
#  'num_contacts_in_campaign',
#  'days_since_prev_campaign_contact',
#  'num_contacts_prev_campaign',
#  'prev_campaign_outcome']

# %%
fig, axes = plt.subplots(7, 1, figsize=(8,20))
for i, c in enumerate(df[num_cols]):
    df[[c]].boxplot(ax=axes[i], vert=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 fig, axes = plt.subplots(7, 1, figsize=(8,20))
#       2 for i, c in enumerate(df[num_cols]):
# ----> 3     df[[c]].boxplot(ax=axes[i], vert=False)
#
# File c:\Python314\Lib\site-packages\pandas\plotting\_core.py:653, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     481 """
#     482 Make a box plot from DataFrame columns.
#     483
#    (...)    649     <class 'numpy.ndarray'>
#     650 """
#     652 plot_backend = _get_plot_backend(backend)
# --> 653 return plot_backend.boxplot_frame(
#     654     self,
#     655     column=column,
#     656     by=by,
#     657     ax=ax,
#     658     fontsize=fontsize,
#     659     rot=rot,
#     660     grid=grid,
#     661     figsize=figsize,
#     662     layout=layout,
#     663     return_type=return_type,
#     664     **kwargs,
#     665 )
#
# File c:\Python314\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:490, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     475 def boxplot_frame(
#     476     self,
#     477     column=None,
#    (...)    486     **kwds,
#     487 ):
#     488     import matplotlib.pyplot as plt
# --> 490     ax = boxplot(
#     491         self,
#     492         column=column,
#     493         by=by,
#     494         ax=ax,
#     495         fontsize=fontsize,
#     496         grid=grid,
#     497         rot=rot,
#     498         figsize=figsize,
#     499         layout=layout,
#     500         return_type=return_type,
#     501         **kwds,
#     502     )
#     503     plt.draw_if_interactive()
#     504     return ax
#
# File c:\Python314\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:461, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     459 naxes = len(data.columns)
#     460 if naxes == 0:
# --> 461     raise ValueError(
#     462         "boxplot method requires numerical columns, nothing to plot."
#     463     )
#     464 if columns is None:
#     465     columns = data.columns
#
# ValueError: boxplot method requires numerical columns, nothing to plot.

# %%
fig, axes = plt.subplots(4, 2, figsize=(18,14))
axes = [ax for axes_rows in axes for ax in axes_rows]

for i, c in enumerate(num_cols):
    plot = df[[c]].plot(kind='kde', ax=axes[i])

# %%
sns.set(font_scale = 1.3)

fig, axes = plt.subplots(4, 2, figsize=(18, 20))
axes = [ax for axes_row in axes for ax in axes_row]

for i, c in enumerate(num_cols):
    df.groupby(target_col)[c].median().plot(kind = 'barh', title=f'Median_{c}', ax=axes[i])

# %%
df['is_old'] = True

df.loc[df['customer_age'] <= 50, 'is_old'] = False

_ = df.groupby('is_old')[target_col].mean().sort_values().plot(kind = 'barh', title='Probability of subscribing to a term deposit')
