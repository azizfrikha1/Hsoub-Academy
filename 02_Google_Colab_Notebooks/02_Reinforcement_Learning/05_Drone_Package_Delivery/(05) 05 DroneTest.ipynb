# %% [markdown]
# ### ⚠️ Patched for Local Execution
# This notebook was originally designed for Google Colab. It has been automatically patched:
# - Google Colab-specific imports and `drive.mount()` calls have been commented out
# - Colab file paths (`/content/drive/...`) have been replaced with relative paths (`./`)
# - `!pip install` commands have been commented out (install packages in your venv instead)
#
# **To run locally:** activate your Python virtual environment first, then run this notebook in VS Code or Jupyter.

# %%
# [PATCHED] !pip install gymnasium
# مكتبة لاستيراد ملفات الشيفرة
# [PATCHED] !pip install nbimporter

# %%
# [PATCHED] from google.colab import drive
# [PATCHED] drive.mount('./')
# صنف استيراد ملفات الشيفرة
import nbformat
# مسار ملف الصنف
class_file_path = './(05) 02 03 DroneEnv.ipynb'
# تحميل ملف شيفرة الصنف
# تحميل ملف شيفرة الصنف
with open(class_file_path, 'r', encoding='utf-8') as f:
    notebook = nbformat.read(f, as_version=4)
# تنفيذ خلايا الشيفرة
for cell in notebook.cells:
    if cell.cell_type == "code":
        try:
            exec(cell.source)
        except Exception as e:
            print(f"Error executing cell: {e}")

# %%
import pickle
def load_q_table_and_env(q_table_file, env_file):
    # تحميل مصفوفة القيم
    with open(q_table_file, 'rb') as f:
        q_table = pickle.load(f)
    # تحميل البيئة
    with open(env_file, 'rb') as f:
        env = pickle.load(f)
    return q_table, env

# %%
# مسار مجلد العمل
working_folder='./'
# مسار ملف مصفوفة القيم
q_table_Drone_path = working_folder + "q_table_Drone.pkl"
# مسار ملف البيئة
env_pkl_Drone_path = working_folder + "env_pkl_Drone.pkl"

# %%
# تحميل مصفوفة القيم والبيئة
q_table, env = load_q_table_and_env(q_table_Drone_path, env_pkl_Drone_path)

# %%
# إعادة تهيئة البيئة للاختبار
env.reset()
done = False
total_reward = 0

# تحديد الهدف
goal_position = [9, 0, 8]
raw_env = env.unwrapped
raw_env.set_goal(goal_position )
# الحالة الحالية
state=raw_env.position_to_state(goal_position)

# حلقة الاختبار لتقييم أداء الوكيل بعد التدريب
while not done:
    action = np.argmax(q_table[state])  # اختيار أفضل فعل من جدول
    # اتخاذ الفعل واكتساب المكافأة
    state, reward, terminated, truncated, info = env.step(action)

    total_reward += reward  # جمع المكافآت خلال الاختبار

    # التحقق مما إذا كانت الحلقة قد انتهت
    if terminated or truncated:
        done = True

# طباعة المكافأة الإجمالية بعد اختبار الوكيل
print(f"Total Reward after Test: {total_reward}")
# الإظهار
env.render()
# Out:
# Total Reward after Test: 976

# %%
# مكتبة الزمن
import time
# مكتبة الإظهار على كولاب
from IPython.display import clear_output

# إعادة تهيئة البيئة للاختبار
env.reset()
done = False
total_reward = 0

# تحديد الهدف
goal_position = [9, 0, 8]
raw_env = env.unwrapped
raw_env.set_goal(goal_position )
# الحالة الحالية
state=raw_env.position_to_state(goal_position)

# حلقة الاختبار لتقييم أداء الوكيل بعد التدريب
while not done:
    action = np.argmax(q_table[state])  # اختيار أفضل فعل من جدول
    # اتخاذ الفعل واكتساب المكافأة
    state, reward, terminated, truncated, info = env.step(action)
    # الإظهار
    env.render()
    # التوقف لثانية
    time.sleep(1)
    # مسح كل الإظهار
    # clear_output()
    total_reward += reward  # جمع المكافآت خلال الاختبار

    # التحقق مما إذا كانت الحلقة قد انتهت
    if terminated or truncated:
        done = True
