# %% [markdown]
# ### ⚠️ Patched for Local Execution
# This notebook was originally designed for Google Colab. It has been automatically patched:
# - Google Colab-specific imports and `drive.mount()` calls have been commented out
# - Colab file paths (`/content/drive/...`) have been replaced with relative paths (`./`)
# - `!pip install` commands have been commented out (install packages in your venv instead)
#
# **To run locally:** activate your Python virtual environment first, then run this notebook in VS Code or Jupyter.

# %%
# [PATCHED] from google.colab import drive
# [PATCHED] drive.mount('./')

# %%
# [PATCHED] !pip install fasttext

# %%
import fasttext
new_text_data_path='./data.txt'
new_model = fasttext.train_supervised(new_text_data_path)
# Out:
# Read 0M words
# Number of words:  28
# Number of labels: 0
# Progress: 100.0% words/sec/thread:     106 lr:  0.000000 avg.loss:      -nan ETA:   0h 0m 0s

# %%
new_model_path='./new_fasttext_model.bin'
new_model.save_model(new_model_path)

# %%
new_model = fasttext.load_model(new_model_path)

# %%
new_model.get_words()
# Out:
# ['</s>',
#  'الرحمن',
#  'الرحيم',
#  'عليهم',
#  'وإياك',
#  'آمين',
#  'الضالين',
#  'ولا',
#  'المغضوب',
#  'غير',
#  'أنعمت',
#  'الذين',
#  'صراط',
#  'المستقيم',
#  'الصراط',
#  'اهدنا',
#  'نستعين',
#  'بسم',
#  'نعبد',
#  'إياك',
#  'الدين',
#  'يوم',
#  'مالك',
#  'العالمين',
#  'رب',
#  'لله',
#  'الحمد',
#  'الله']

# %%
word="الرحمن"
word_embedding = new_model[word]
word_embedding
# Out:
# array([ 0.00238093,  0.00509113,  0.00831976, -0.00927015,  0.00661152,
#         0.00807286, -0.00648016,  0.00133566, -0.00343636, -0.00210862,
#        -0.00070896, -0.00633463, -0.00485001,  0.00221098, -0.00606992,
#        -0.00717415,  0.00338688,  0.00603667, -0.00688208, -0.00057144,
#        -0.00488543,  0.00987955,  0.00397523,  0.00694702, -0.00861237,
#        -0.00616428, -0.00983707, -0.00120694, -0.00220774, -0.00728686,
#        -0.00501538, -0.00077216,  0.00396778, -0.00586287, -0.00635476,
#        -0.00211214, -0.00715075,  0.00431303, -0.00053761, -0.0027656 ,
#        -0.0099938 ,  0.00944217, -0.00514806,  0.00308559,  0.00880401,
#         0.00192514,  0.00807715, -0.00336937, -0.00391913,  0.00350796,
#        -0.00100431, -0.00181935,  0.0023661 ,  0.00489011, -0.00905311,
#         0.00352073, -0.00963604,  0.0006935 ,  0.00876348, -0.00243911,
#        -0.00015379,  0.00351502,  0.00568376,  0.00787363,  0.00454237,
# ...

# %%
#https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.ar.300.vec.gz

# %%
pre_trained_model_path='./cc.ar.300.bin'

# %%
fine_tuned_model = fasttext.train_unsupervised(new_text_data_path,
                                               dim=300,
                                               pretrainedVectors=pre_trained_model_path)
# Out:
# Read 0M words
# Number of words:  1
# Number of labels: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 fine_tuned_model = fasttext.train_unsupervised(new_text_data_path,
#       2                                                dim=300,
#       3                                                pretrainedVectors=pre_trained_model_path)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.11/site-packages/fasttext/FastText.py:604, in train_unsupervised(*kargs, **kwargs)
#     602 a = _build_args(args, manually_set_args)
#     603 ft = _FastText(args=a)
# --> 604 fasttext.train(ft.f, a)
#     605 ft.set_args(ft.f.getArgs())
#     606 return ft
#
# ValueError: Dimension of pretrained vectors (4037048710369390848) does not match dimension (300)!

# %%
fine_tuned_model_path="./fine_tuned_model.bin"
fine_tuned_model.save_model(fine_tuned_model_path)

# %%
fine_tuned_model = fasttext.load_model(fine_tuned_model_path)
word="الرحمن"
word_embedding = fine_tuned_model.get_word_vector(word)
word_embedding
