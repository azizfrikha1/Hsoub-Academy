# %%
model_name = 'nlptown/bert-base-multilingual-uncased-sentiment'

# %%
"https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment"
# Out:
# 'https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment'

# %%
sentiment_mapping = {
    0: 'very negative',
    1: 'negative',
    2: 'neutral',
    3: 'positive',
    4: 'very positive'
}

# %%
from transformers import BertTokenizer, BertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)  # Removed num_labels=2
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
text = "I like my job"

# %%
inputs = tokenizer(text, return_tensors='pt')
input_ids = inputs['input_ids']

# %%
import torch

text = "I like my job"
inputs = tokenizer(text, return_tensors='pt')

with torch.no_grad():
    outputs = model(**inputs)
    logits = outputs.logits

predicted_class = torch.argmax(logits, dim=-1).item()
predicted_sentiment = sentiment_mapping[predicted_class]
print(f"The text is predicted to have a sentiment: {predicted_sentiment}")
# Out:
# The text is predicted to have a sentiment: positive

# %%
import numpy as np
predicted_class = np.argmax(logits)
predicted_class
# Out:
# tensor(3)

# %%
sentiment_mapping = {
    0: 'very negative',
    1: 'negative',
    2: 'neutral',
    3: 'positive',
    4: 'very positive'
}

predicted_class = torch.argmax(logits, dim=-1).item()
predicted_sentiment = sentiment_mapping[predicted_class]
print("The text is predicted to have a sentiment: {}".format(predicted_sentiment))
# Out:
# The text is predicted to have a sentiment: positive

# %%
import torch

text = "I hate my job"
inputs = tokenizer(text, return_tensors='pt')

# Pass unpacked inputs through the PyTorch model
with torch.no_grad():
    outputs = model(**inputs)
    logits = outputs.logits

# Extract predicted class as a Python integer
predicted_class = torch.argmax(logits, dim=-1).item()
predicted_sentiment = sentiment_mapping[predicted_class]

print("The text is predicted to have a sentiment: {}".format(predicted_sentiment))
# Out:
# The text is predicted to have a sentiment: very negative
