# %% [markdown]
# ### ⚠️ Patched for Local Execution
# This notebook was originally designed for Google Colab. It has been automatically patched:
# - Google Colab-specific imports and `drive.mount()` calls have been commented out
# - Colab file paths (`/content/drive/...`) have been replaced with relative paths (`./`)
# - `!pip install` commands have been commented out (install packages in your venv instead)
#
# **To run locally:** activate your Python virtual environment first, then run this notebook in VS Code or Jupyter.

# %%
# %pip install openai

# %%
from openai import OpenAI

# Initialize the OpenAI client
# Replace with your fresh API key (never share your key in public!)
client = OpenAI(api_key="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")

PROMPT = "Picture of an old computer"

try:
    response = client.images.generate(
        model="dall-e-3",      # Changed from deprecated 'dall-e-2'
        prompt=PROMPT,
        n=1,
        size="1024x1024"      # Standard size supported by DALL-E 3
    )

    # Print the public URL of the generated image
    print(response.data[0].url)

except Exception as e:
    print(f"Error generating image: {e}")
# Out:
# Error: Error code: 400 - {'error': {'message': 'Billing hard limit has been reached.', 'type': 'billing_limit_user_error', 'param': None, 'code': 'billing_hard_limit_reached'}}

# %%
print(response.data[0].url)

# %%
# [PATCHED] from google.colab import drive
# [PATCHED] drive.mount('./')

# %%
import os
IMAGE_PATH = './img.png' if os.path.exists('./img.png') else 'DALL.E/img.png'

response = client.images.create_variation(
    model="dall-e-2",
    image=open(IMAGE_PATH, mode="rb"),
    n=3,
    size="256x256",
)

# %%
print(response)

# %%
print(response.data[0].url)

# %%
print(response.data[1].url)

# %%
print(response.data[2].url)

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="Picture of an old computer",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
image_url
