# %% [markdown]
# ### ⚠️ Patched for Local Execution
# This notebook was originally designed for Google Colab. It has been automatically patched:
# - Google Colab-specific imports and `drive.mount()` calls have been commented out
# - Colab file paths (`/content/drive/...`) have been replaced with relative paths (`./`)
# - `!pip install` commands have been commented out (install packages in your venv instead)
#
# **To run locally:** activate your Python virtual environment first, then run this notebook in VS Code or Jupyter.

# %%
# %pip install ultralytics opencv-python matplotlib easyocr
# Out:
# Requirement already satisfied: ultralytics in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (8.4.112)
# Requirement already satisfied: opencv-python in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (5.0.0.93)
# Requirement already satisfied: matplotlib in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (3.11.1)
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (3.29.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (2.4.4)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (1.43.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.2 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from ultralytics) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting opencv-python-headless (from easyocr)
#   Downloading opencv_python_headless-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from easyocr) (1.18.0)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting python-bidi (from easyocr)
#   Using cached python_bidi-0.6.11-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.4.0-cp312-cp312-win_amd64.whl.metadata (8.8 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: polars-runtime-32==1.43.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.43.1)
# Requirement already satisfied: six>=1.5 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: setuptools in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->easyocr)
#   Downloading imageio-2.37.4-py3-none-any.whl.metadata (9.6 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2026.7.14-py3-none-any.whl.metadata (33 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aziz1\onedrive\desktop\hsoub academy\ok\02_google_colab_notebooks\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------------------ --------------------- 1.3/2.9 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 5.6 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Downloading opencv_python_headless-5.0.0.93-cp37-abi3-win_amd64.whl (43.8 MB)
#    ---------------------------------------- 0.0/43.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.8 MB ? eta -:--:--
#     --------------------------------------- 1.0/43.8 MB ? eta -:--:--
#    - -------------------------------------- 1.6/43.8 MB 6.0 MB/s eta 0:00:08
#    -- ------------------------------------- 2.4/43.8 MB 5.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/43.8 MB 6.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.3/43.8 MB 7.6 MB/s eta 0:00:05
#    ------ --------------------------------- 7.6/43.8 MB 7.5 MB/s eta 0:00:05
#    -------- ------------------------------- 8.9/43.8 MB 7.1 MB/s eta 0:00:05
#    --------- ------------------------------ 10.2/43.8 MB 6.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 11.5/43.8 MB 6.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.8/43.8 MB 6.8 MB/s eta 0:00:05
#    ------------ --------------------------- 14.2/43.8 MB 6.7 MB/s eta 0:00:05
#    -------------- ------------------------- 15.5/43.8 MB 6.7 MB/s eta 0:00:05
#    -------------- ------------------------- 16.3/43.8 MB 6.6 MB/s eta 0:00:05
#    --------------- ------------------------ 17.0/43.8 MB 6.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 17.8/43.8 MB 6.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 18.4/43.8 MB 6.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 19.1/43.8 MB 5.8 MB/s eta 0:00:05
#    ------------------ --------------------- 19.9/43.8 MB 5.7 MB/s eta 0:00:05
#    ------------------- -------------------- 21.0/43.8 MB 5.6 MB/s eta 0:00:05
#    ------------------- -------------------- 21.8/43.8 MB 5.5 MB/s eta 0:00:04
#    -------------------- ------------------- 22.5/43.8 MB 5.5 MB/s eta 0:00:04
#    --------------------- ------------------ 23.6/43.8 MB 5.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 24.4/43.8 MB 5.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 25.4/43.8 MB 5.4 MB/s eta 0:00:04
#    ------------------------ --------------- 26.5/43.8 MB 5.3 MB/s eta 0:00:04
#    ------------------------- -------------- 27.5/43.8 MB 5.3 MB/s eta 0:00:04
#    -------------------------- ------------- 28.6/43.8 MB 5.3 MB/s eta 0:00:03
#    --------------------------- ------------ 29.6/43.8 MB 5.3 MB/s eta 0:00:03
#    --------------------------- ------------ 30.7/43.8 MB 5.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 31.7/43.8 MB 5.3 MB/s eta 0:00:03
#    ------------------------------ --------- 33.0/43.8 MB 5.3 MB/s eta 0:00:03
#    ------------------------------- -------- 34.1/43.8 MB 5.3 MB/s eta 0:00:02
#    -------------------------------- ------- 35.4/43.8 MB 5.4 MB/s eta 0:00:02
#    --------------------------------- ------ 36.7/43.8 MB 5.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.0/43.8 MB 5.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/43.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 40.6/43.8 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 41.9/43.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  43.3/43.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 43.8/43.8 MB 5.5 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-win_amd64.whl (104 kB)
# Using cached python_bidi-0.6.11-cp312-cp312-win_amd64.whl (161 kB)
# Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl (11.9 MB)
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.9 MB 6.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/11.9 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.9 MB 7.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.5/11.9 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.1/11.9 MB 7.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.7/11.9 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 10.0/11.9 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/11.9 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.9/11.9 MB 6.8 MB/s eta 0:00:00
# Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.8 MB/s eta 0:00:00
# Downloading imageio-2.37.4-py3-none-any.whl (318 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading tifffile-2026.7.14-py3-none-any.whl (270 kB)
# Installing collected packages: tifffile, Shapely, python-bidi, pyclipper, opencv-python-headless, ninja, lazy-loader, imageio, scikit-image, easyocr
# Successfully installed Shapely-2.1.2 easyocr-1.7.2 imageio-2.37.4 lazy-loader-0.5 ninja-1.13.0 opencv-python-headless-5.0.0.93 pyclipper-1.4.0 python-bidi-0.6.11 scikit-image-0.26.0 tifffile-2026.7.14
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import easyocr
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\aziz1\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8x.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8x.pt to 'yolov8x.pt': 100% ━━━━━━━━━━━━ 130.5MB 4.0MB/s 32.5s32.5s<0.0ss

# %%
# [PATCHED] from google.colab import drive
# [PATCHED] drive.mount('./')

# %%
import os
image_path = 'car.jpg' if os.path.exists('car.jpg') else 'car_plate/car.jpg'

# %%
image = cv2.imread(image_path)

results = model.predict(image)

reader = easyocr.Reader(['en'])

result = results[0]

result
# Out:
# 0: 640x480 1 car, 23.1ms
# Speed: 91.4ms preprocess, 23.1ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 480)
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[150, 146, 121],
#         [146, 149, 127],
#         [140, 152, 132],
#         ...,
#         [132, 158, 165],
#         [131, 157, 164],
#         [131, 157, 164]],
#
#        [[153, 142, 115],
#         [147, 145, 121],
#         [139, 150, 130],
#         ...,
#         [131, 157, 164],
#         [130, 156, 163],
#         [130, 156, 163]],
#
#        [[173, 152, 121],
#         [162, 151, 124],
#         [147, 150, 128],
#         ...,
#         [131, 157, 164],
#         [130, 156, 163],
#         [130, 156, 163]],
#
#        ...,
#
#        [[143, 133, 123],
#         [135, 125, 115],
#         [137, 127, 117],
#         ...,
#         [ 83,  78,  79],
#         [ 67,  61,  62],
#         [ 69,  63,  64]],
#
#        [[144, 134, 124],
#         [137, 127, 117],
#         [139, 129, 119],
#         ...,
#         [ 87,  82,  83],
#         [ 69,  63,  64],
#         [ 64,  58,  59]],
#
#        [[143, 133, 123],
#         [135, 125, 115],
#         [137, 127, 117],
#         ...,
#         [ 92,  87,  88],
#         [ 84,  78,  79],
#         [ 80,  74,  75]]], shape=(500, 375, 3), dtype=uint8)
# orig_shape: (500, 375)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\aziz1\\OneDrive\\Desktop\\hsoub academy\\ok\\02_Google_Colab_Notebooks\\01_Computer_Vision\\Large_Vision_Models\\car_plate\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 91.39370000048075, 'inference': 23.081200000888202, 'postprocess': 17.125900005339645}

# %%
license_plates_text = []
for box in result.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
    class_id = int(box.cls.tolist()[0])
    label = result.names[class_id]

    if label in ["car", "vehicle"]:

        license_plate_img = image[y1:y2, x1:x2]

        license_plate_img_gray = cv2.cvtColor(license_plate_img, cv2.COLOR_BGR2GRAY)
        _, license_plate_img_binary = cv2.threshold(license_plate_img_gray, 128, 255, cv2.THRESH_BINARY_INV)

        plt.imshow(license_plate_img_gray)
        plt.show()
        plt.imshow(license_plate_img_binary)
        plt.show()

        plate_text = reader.readtext(license_plate_img_binary, detail=0)

        plate_text_combined = ' '.join(plate_text)

        if plate_text_combined:
            license_plates_text.append(plate_text_combined)

            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, plate_text_combined, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
if license_plates_text:
    print("نصوص لوحات السيارات المكتشفة:")
    for i, plate_text in enumerate(license_plates_text, 1):
        print(f"{plate_text}")
else:
    print("لم يتم العثور على لوحات سيارات في الصورة.")
# Out:
# نصوص لوحات السيارات المكتشفة:
# E796 KOY

# %%
def detect_and_read_license_plates(image_path):

    model = YOLO('yolov8x.pt')

    image = cv2.imread(image_path)

    results = model.predict(image_path)

    reader = easyocr.Reader(['en'])

    result = results[0]

    license_plates_text = []
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
        class_id = int(box.cls.tolist()[0])
        label = result.names[class_id]

        if label in ["car", "vehicle"]:

            license_plate_img = image[y1:y2, x1:x2]

            license_plate_img_gray = cv2.cvtColor(license_plate_img, cv2.COLOR_BGR2GRAY)
            _, license_plate_img_binary = cv2.threshold(license_plate_img_gray, 128, 255, cv2.THRESH_BINARY_INV)

            plt.imshow(license_plate_img_gray)
            plt.show()
            plt.imshow(license_plate_img_binary)
            plt.show()

            plate_text = reader.readtext(license_plate_img_binary, detail=0)

            plate_text_combined = ' '.join(plate_text)

            if plate_text_combined:
                license_plates_text.append(plate_text_combined)

                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(image, plate_text_combined, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    if license_plates_text:
        print("نصوص لوحات السيارات المكتشفة:")
        for i, plate_text in enumerate(license_plates_text, 1):
            print(f"{plate_text}")
    else:
        print("لم يتم العثور على لوحات سيارات في الصورة.")

# %%
import os
detect_and_read_license_plates('car.jpg' if os.path.exists('car.jpg') else 'car_plate/car.jpg')
# Out:
# image 1/1 c:\Users\aziz1\OneDrive\Desktop\hsoub academy\ok\02_Google_Colab_Notebooks\01_Computer_Vision\Large_Vision_Models\car_plate\car.jpg: 640x480 1 car, 88.2ms
# Speed: 2.3ms preprocess, 88.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# نصوص لوحات السيارات المكتشفة:
# E796 KOY

# %%
import os
detect_and_read_license_plates('car2.jpg' if os.path.exists('car2.jpg') else 'car_plate/car2.jpg')
# Out:
# image 1/1 c:\Users\aziz1\OneDrive\Desktop\hsoub academy\ok\02_Google_Colab_Notebooks\01_Computer_Vision\Large_Vision_Models\car_plate\car2.jpg: 352x640 2 cars, 19.5ms
# Speed: 1.4ms preprocess, 19.5ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
# نصوص لوحات السيارات المكتشفة:
# 2 BE
# NOT2B
